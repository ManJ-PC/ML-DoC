# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#! pip install pandas
#! conda env list
#df = pd.read_csv("ComaSessions.csv")
#df.head()

# %% [markdown]
# # Setup

# %%
url = 'https://raw.githubusercontent.com/Camolas/ML_DOC/master/Databases/SmartAvaliationPrototype.csv'

# %%
from numpy import genfromtxt
my_data = genfromtxt('https://raw.githubusercontent.com/Camolas/ML_DOC/master/Databases/SmartAvaliationPrototype.csv', delimiter=',') # Using Numpy Arrays

# %%
type(my_data)
# Out:
# numpy.ndarray

# %%
docDF = pd.read_csv(url) #Using Dataframes
docDf = pd.read_csv(url) #Using to ML 3 States

# %%
type(docDF)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data Analysis

# %%
docDF.head()
# Out:
#    Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0      1   1  ...                    2                    100
# 1      2   2  ...                    2                    100
# 2      3   3  ...                    2                    100
# 3      4   4  ...                    1                     80
# 4      5   5  ...                    2                    100
#
# [5 rows x 148 columns]

# %%
docDF.shape #We have 35 lines and 148 columns of data
# Out:
# (35, 148)

# %%
print(my_data)
# Out:
# [[ nan  nan  nan ...  nan  nan  nan]
#  [  1.   1.   1. ... 100.   2. 100.]
#  [  2.   2.   2. ... 100.   2. 100.]
#  ...
#  [ 33.  50.   2. ... 100.   2. 100.]
#  [ 34.  51.   2. ... 100.   2. 100.]
#  [ 35.  52.   2. ... 100.   2. 100.]]

# %%
docDF.describe()
# Out:
#            Order         ID  ...  BothRatersSession10  BothRatersCertainty10
# count  35.000000  35.000000  ...            35.000000              35.000000
# mean   18.000000  29.000000  ...             1.685714              98.571429
# std    10.246951  16.615018  ...             0.471008               4.936572
# min     1.000000   1.000000  ...             1.000000              80.000000
# 25%     9.500000  14.000000  ...             1.000000             100.000000
# 50%    18.000000  33.000000  ...             2.000000             100.000000
# 75%    26.500000  42.500000  ...             2.000000             100.000000
# max    35.000000  52.000000  ...             2.000000             100.000000
#
# [8 rows x 132 columns]

# %%
docDF['Age'].plot(kind='box', vert=False, figsize=(14,6)) #Here I think that We don't have columns with outliers (limits very defined because we use escales in SMARTecnique)

# %%
docDF['Age'].plot(kind='density',figsize=(14,6)) #kde

# %%
ax = docDF['Age'].plot(kind='density',figsize=(14,6)) #kde
ax.axvline(docDF['Age'].mean(), color='red')
ax.axvline(docDF['Age'].median(), color='green')

# %%
ax2 = docDF['Age'].plot(kind='hist', figsize=(14,6))
ax2.set_ylabel('Freq.doGrupoEtário')
ax2.set_xlabel('idade')
# Out:
# Text(0.5, 0, 'idade')

# %%
docDF.info() # as we have a lot of Columns We don't describe (numerating, describing, and secure non-Null Count, see Dtype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Columns: 148 entries, Order to BothRatersCertainty10
# dtypes: int64(132), object(16)
# memory usage: 40.6+ KB

# %% [markdown]
# # Data Analysis 2nd Part

# %%
docDF['Diagnostic3Levels'].value_counts()
# Out:
# 3    14
# 2    11
# 1    10
# Name: Diagnostic3Levels, dtype: int64

# %%
docDF['Diagnostic'].value_counts()
# Out:
# 2    25
# 1    10
# Name: Diagnostic, dtype: int64

# %%
docDF['Sex'].value_counts()
# Out:
# 2    28
# 1     7
# Name: Sex, dtype: int64

# %%
docDF['Etiology'].value_counts()
# Out:
# 2    24
# 1    11
# Name: Etiology, dtype: int64

# %%
docDF #In Diagnostic: 1 is Vegetative and 2 is Min. Consciousness
      #In Diagnostic3Levels: 2 is MCS- 
                            #3 is MCS+
# Out:
#     Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0       1   1  ...                    2                    100
# 1       2   2  ...                    2                    100
# 2       3   3  ...                    2                    100
# 3       4   4  ...                    1                     80
# 4       5   5  ...                    2                    100
# 5       6   6  ...                    2                    100
# 6       7   7  ...                    1                    100
# 7       8   8  ...                    2                    100
# 8       9   9  ...                    1                    100
# 9      10  19  ...                    2                     90
# 10     11  22  ...                    2                    100
# 11     12  23  ...                    2                    100
# 12     13  25  ...                    2                    100
# 13     14  26  ...                    2                    100
# ...

# %%
docDF.isnull().sum() #Missing values flagged by NA , aqui eles são 'NA '
# Out:
# Order                    0
# ID                       0
# Sex                      0
# Age                      0
# Etiology                 0
#                         ..
# BothRatersCertainty8     0
# BothRatersSession9       0
# BothRatersCertainty9     0
# BothRatersSession10      0
# BothRatersCertainty10    0
# Length: 148, dtype: int64

# %%
docDF.shape
# Out:
# (35, 148)

# %%
docDF.size
# Out:
# 5180

# %%
35*148
# Out:
# 5180

# %%
len(docDF)
# Out:
# 35

# %%
docDF.shape[1]
# Out:
# 148

# %%
docDF.loc[0,'Order'] # label-based
# Out:
# 1

# %%
docDF.iloc[len(docDF)-1,0]
# Out:
# 35

# %%
docDF.loc[8,'Visual1']
# Out:
# ' NA'

# %%
count = 0
for i in range(0, len(docDF)-1):
  for j in range(0, docDF.shape[1]):
    if docDF.iloc[i,j] == ' NA': 
      count = count + 1
print(count)
# Out:
# 111

# %%
#docDF[df] this is a comment in Python using '#' before the sentence

# %%
docDF.groupby(['Etiology']).mean()
# Out:
#               Order         ID  ...  BothRatersSession10  BothRatersCertainty10
# Etiology                        ...
# 1         19.727273  31.181818  ...             1.727273              98.181818
# 2         17.208333  28.000000  ...             1.666667              98.750000
#
# [2 rows x 131 columns]

# %%
docDF.groupby(['Diagnostic']).mean()
# Out:
#             Order     ID  ...  BothRatersSession10  BothRatersCertainty10
# Diagnostic                ...
# 1           21.20  33.70  ...                 1.00                  100.0
# 2           16.72  27.12  ...                 1.96                   98.0
#
# [2 rows x 131 columns]

# %% [markdown]
# # Data Cleaning

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
 
#labels = docDF.loc['Diagnostic']
#labels  # label will be the diagnostic?

# %%
docDF
# Out:
#     Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0       1   1  ...                    2                    100
# 1       2   2  ...                    2                    100
# 2       3   3  ...                    2                    100
# 3       4   4  ...                    1                     80
# 4       5   5  ...                    2                    100
# 5       6   6  ...                    2                    100
# 6       7   7  ...                    1                    100
# 7       8   8  ...                    2                    100
# 8       9   9  ...                    1                    100
# 9      10  19  ...                    2                     90
# 10     11  22  ...                    2                    100
# 11     12  23  ...                    2                    100
# 12     13  25  ...                    2                    100
# 13     14  26  ...                    2                    100
# ...

# %%
#labels = docDF.iloc[:,6]
#labels

# %%
data =  pd.concat([docDF.iloc[:,:6],docDF.iloc[:,7:]]) #gives NaN , why? I don't know... making joining bad not detect connections

# %%
df1 = docDF.iloc[:,:6]

# %%
df2 = docDF.iloc[:,7:]

# %%
data
# Out:
#     Order   ID  ...  BothRatersSession10  BothRatersCertainty10
# 0     1.0  1.0  ...                  NaN                    NaN
# 1     2.0  2.0  ...                  NaN                    NaN
# 2     3.0  3.0  ...                  NaN                    NaN
# 3     4.0  4.0  ...                  NaN                    NaN
# 4     5.0  5.0  ...                  NaN                    NaN
# ..    ...  ...  ...                  ...                    ...
# 30    NaN  NaN  ...                  2.0                  100.0
# 31    NaN  NaN  ...                  2.0                   80.0
# 32    NaN  NaN  ...                  2.0                  100.0
# 33    NaN  NaN  ...                  2.0                  100.0
# 34    NaN  NaN  ...                  2.0                  100.0
#
# [70 rows x 147 columns]

# %%
df1 = docDF.pop('Diagnostic') # remove column Diag and store it in df1

# %%
df1
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     1
# 7     2
# 8     1
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    1
# 19    1
# 20    1
# 21    2
# 22    2
# 23    1
# 24    2
# 25    1
# 26    1
# 27    2
# 28    1
# 29    1
# 30    2
# 31    2
# 32    2
# 33    2
# 34    2
# Name: Diagnostic, dtype: int64

# %%
docDF
# Out:
#     Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0       1   1  ...                    2                    100
# 1       2   2  ...                    2                    100
# 2       3   3  ...                    2                    100
# 3       4   4  ...                    1                     80
# 4       5   5  ...                    2                    100
# 5       6   6  ...                    2                    100
# 6       7   7  ...                    1                    100
# 7       8   8  ...                    2                    100
# 8       9   9  ...                    1                    100
# 9      10  19  ...                    2                     90
# 10     11  22  ...                    2                    100
# 11     12  23  ...                    2                    100
# 12     13  25  ...                    2                    100
# 13     14  26  ...                    2                    100
# ...

# %%
docDF['Diagnostic']=df1 # add DIag series as a 'new' column.

# %%
docDF
# Out:
#     Order  ID  Sex  ...  BothRatersSession10  BothRatersCertainty10  Diagnostic
# 0       1   1    1  ...                    2                    100           2
# 1       2   2    2  ...                    2                    100           2
# 2       3   3    2  ...                    2                    100           2
# 3       4   4    2  ...                    1                     80           2
# 4       5   5    2  ...                    2                    100           2
# 5       6   6    2  ...                    2                    100           2
# 6       7   7    2  ...                    1                    100           1
# 7       8   8    2  ...                    2                    100           2
# 8       9   9    1  ...                    1                    100           1
# 9      10  19    2  ...                    2                     90           2
# 10     11  22    2  ...                    2                    100           2
# ...

# %%
labels = docDF.iloc[:,-1]
labels
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     1
# 7     2
# 8     1
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    1
# 19    1
# 20    1
# 21    2
# 22    2
# 23    1
# 24    2
# 25    1
# 26    1
# 27    2
# 28    1
# 29    1
# 30    2
# 31    2
# 32    2
# 33    2
# 34    2
# Name: Diagnostic, dtype: int64

# %%
data = docDF.iloc[:,:-1] #remove a y_label
data
# Out:
#     Order  ID  ...  BothRatersSession10  BothRatersCertainty10
# 0       1   1  ...                    2                    100
# 1       2   2  ...                    2                    100
# 2       3   3  ...                    2                    100
# 3       4   4  ...                    1                     80
# 4       5   5  ...                    2                    100
# 5       6   6  ...                    2                    100
# 6       7   7  ...                    1                    100
# 7       8   8  ...                    2                    100
# 8       9   9  ...                    1                    100
# 9      10  19  ...                    2                     90
# 10     11  22  ...                    2                    100
# 11     12  23  ...                    2                    100
# 12     13  25  ...                    2                    100
# 13     14  26  ...                    2                    100
# ...

# %%
pd.set_option('max_columns', None)

# %%
data
# Out:
#     Order  ID  Sex  Age  Etiology  Time  Diagnostic3Levels Visual1 Visual2  \
# 0       1   1    1   41         2     5                  3       4       4
# 1       2   2    2   43         1     6                  3       5       5
# 2       3   3    2   67         1     8                  2       3       1
# 3       4   4    2   65         2     4                  2       2       4
# 4       5   5    2   63         2     8                  2       4       4
# 5       6   6    2   57         2     6                  2       2       3
# 6       7   7    2   35         2     7                  1       3       2
# 7       8   8    2   24         1     5                  2       4       1
# 8       9   9    1   53         2     5                  1      NA      NA
# 9      10  19    2   56         2     6                  3       1       2
# 10     11  22    2   70         2     4                  3       4       5
# ...

# %%
data.iloc[0]
# Out:
# Order                      1
# ID                         1
# Sex                        1
# Age                       41
# Etiology                   2
#                         ...
# BothRatersCertainty8     100
# BothRatersSession9         2
# BothRatersCertainty9     100
# BothRatersSession10        2
# BothRatersCertainty10    100
# Name: 0, Length: 147, dtype: object

# %%
plt.scatter(docDF['Etiology'],docDF['Diagnostic3Levels']) #Pouco interessante, contudo se colocar a frequência, muda de perspectiva

# %%
freq = (docDF['Etiology'],docDF['Diagnostic3Levels'])

# %%
#freq.value_counts() not a dataframe is a tuple , freq.describe()
#print(freq) ñ interessa
docDF['Diagnostic3Levels'].value_counts()
# Out:
# 3    14
# 2    11
# 1    10
# Name: Diagnostic3Levels, dtype: int64

# %%
docDF['Diagnostic3Levels'].value_counts().plot(kind='pie', figsize=(6,6))

# %%
ax3 = docDF['Diagnostic3Levels'].value_counts().plot(kind='bar', figsize=(14,6))
ax3.set_ylabel('Number of Diagnostics') #3Levels')
# Out:
# Text(0, 0.5, 'Number of Diagnostics')

# %%
ax2C = docDF['Diagnostic'].value_counts().plot(kind='bar', figsize=(14,6))
ax2C.set_ylabel('Number of Diagnostics') #2Levels')
# Out:
# Text(0, 0.5, 'Number of Diagnostics')

# %%
corr = docDF.corr()

# %%
corr
# Out:
#                           Order        ID           Sex       Age  Etiology  \
# Order                  1.000000  0.981928  1.485221e-01 -0.102067 -0.115785
# ID                     0.981928  1.000000  1.134068e-01 -0.089793 -0.090199
# Sex                    0.148522  0.113407  1.000000e+00  0.170541 -0.338502
# Age                   -0.102067 -0.089793  1.705414e-01  1.000000  0.121871
# Etiology              -0.115785 -0.090199 -3.385016e-01  0.121871  1.000000
# ...                         ...       ...           ...       ...       ...
# BothRatersSession9    -0.200392 -0.181519  4.607969e-17  0.331969 -0.019462
# BothRatersCertainty9   0.237646  0.252414 -1.619121e-01 -0.212058 -0.014068
# BothRatersSession10   -0.109691 -0.082683 -3.077287e-02  0.260653 -0.060606
# BothRatersCertainty10  0.046515  0.071717 -1.468051e-01 -0.130189  0.054211
# Diagnostic            -0.200392 -0.181519  4.607969e-17  0.331969 -0.019462
#
# ...

# %%
fig = plt.figure(figsize=(25,25))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
docDF.plot(kind="scatter", x = 'Etiology', y='Age',figsize=(6,6))

# %%
docDF.plot(kind="scatter", x = 'Age', y='Diagnostic3Levels',figsize=(6,6))

# %%
docDF.plot(kind="scatter", x = 'Age', y='Time',figsize=(6,6)) #Fazer um gráfico 3D com,

# %%
ax3 = docDF[['Age','Time']].boxplot(by='Age', figsize=(10,6))
#ax.set_ylabel('Time'), Não faz diferença

# %%
boxplot_cols = ['Sex',	'Age',	'Etiology',	'Time',	'Diagnostic3Levels', 'Diagnostic']
docDF[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))

# %%
#docDF.plot(kind="scatter", x = 'Etiology', y='Time',figsize=(6,6))

# %%
#docDF = docDF.replace(np.nan,'bananas')
#docDF = docDF.fillna('bananas')
#docDF['Visual1'][8]
#docDF = docDF.replace(' NA','bananas')
docDF = docDF.replace('bananas', -1)

docDF #discutir/debater com Proponentes os valores em falta (-1's)

# %%
docDF.loc[8]['Visual1']

# %%
data = data.replace(' NA', -1)

# %%
data

# %%
type(labels)

# %%
count = 0
for i in range(0, len(data)-1):
  for j in range(0, data.shape[1]):
    if data.iloc[i,j] == ' NA': 
      count = count + 1
print(count)

# %%
data.iloc(0)

# %%
data.info()

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data,df1, stratify=df1
) #change df1 for labels

# %%
y_test

# %%
y_test

# %%
labels

# %%
df1

# %%
type(data) #no outro eram np.numarray ... não há problema em trabalhar com estes?

# %%
type(df1)

# %%
print("X_train shape: {}".format(X_train.shape)) # Faz já a divisão de treino: 75% * 35 = 26.25  e teste ...

# %%
print("y_train shape: {}".format(y_train.shape))

# %%
print("X_test shape: {}".format(X_test.shape))

# %%
print("y_test shape: {}".format(y_test.shape))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)

# %%
y_pred = knn.predict(X_test)
print("Test set predictions:\n {}".format(y_pred))

# %%
print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))

# %%
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))

# %%
# criar função ... para reproduzir
X = data # 147 caracteristicas este dataset
y = labels

# uma linha de X bate certo com uma linha de y ... and so on
print(X.iloc[0])
print(y.iloc[0])

lista_vs = [exemplo for exemplo in range(len(y)) if y[exemplo] == 1] # listas por comprensão , filtrar a lista lendo a própria lista (Matrioska effect)
print(lista_vs)
x_vs = X.iloc[lista_vs]
y_vs = y.iloc[lista_vs]
print(len(x_vs))
#
lista_mcs = [exemplo for exemplo in range(len(y)) if y[exemplo] == 0] # operações matriciais, o python poupa muito código ...
print(lista_mcs) 
x_mcs = X.iloc[lista_mcs]
y_mcs = y.iloc[lista_mcs]
print(len(x_mcs)) 
print(len(X))

# %%
lista_vs

# %%
type(X)

# %%
print(data.iloc[0])

print(X.shape)
print(y.shape) # é a 148ª coluna deste conj. de dados

# %%
def model_train_and_evaluate(a_classifier, _x_train, _y_train, _x_test, _y_test, key=""):  # o que acontece com o sklearn, todos os modelos fit e predict tem.. e mudasse o tipo de classificadores aqui

  a_model = a_classifier.fit(_x_train, _y_train) #dá para todos os modelos de classificador que pretenda
# fase de treino e fit -> train , mudou nome das varíaveis para não coincidirem em memória .. é eager precisa dos dados completos para fazer o fit etc
  yproba = a_model.predict_proba(_x_test)[::,1]  # da uma noção e confiança sobre aquela amostra
  ypredicted = a_model.predict(_x_test)
# lista inteira de exemplo, em que depois bate tudo certo...
  # extract metrics  tipically y_true, y_pred # groundtrue  e y que foram previstos.., slides das métricas vai disponibilizar... , matriz de confusão
  fpr, tpr, _ = roc_curve(_y_test, yproba, pos_label=2) #f_measure também!
  auc = roc_auc_score(_y_test, yproba)
  conf_m = confusion_matrix(_y_test, ypredicted) # extraí um conj. de métricas de performance
  mcc = matthews_corrcoef(_y_test, ypredicted)
  f1 = f1_score(_y_test, ypredicted)
  # we can add more..
  result_table = pd.DataFrame(columns=['classifiers', 'fpr', 'tpr', 'auc', 'f1', 'mcc', 'confusion_matrix']) # faz datasets bem construídos e legíveis (dados e visualmente)
  result_table = result_table.append({'classifiers':a_classifier.__class__.__name__+"-"+key,
                                     'fpr':fpr,
                                     'tpr':tpr,
                                     'auc':auc,
                                     'confusion_matrix': conf_m,
                                     'mcc':mcc,
                                     'f1': f1}, ignore_index=True)
  return result_table #fica numa tabela em result

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1234) # devolve uma lista de variáveis (decomposição) separadas por vírgulas, faz o split do dataset total
print(X_train.shape) # rnadom_state com valor fixo para conseguirmos garantir que conseguimos replicar.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import f1_score

results = model_train_and_evaluate(DecisionTreeClassifier(random_state=2020), X_train, y_train, X_test, y_test) # Aproveitar o classificadores que já existem
results.head()

# %%
def plot_roc_insame(result_table):
    result_table.set_index('classifiers', inplace=True)
    
    fig = plt.figure(figsize=(8,6))
    
    for i in result_table.index:
        plt.plot(result_table.loc[i]['fpr'], 
                 result_table.loc[i]['tpr'], 
                 label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
        
    plt.plot([0,1], [0,1], color='black', linestyle='--') # random chance!
    plt.xticks(np.arange(0.0, 1.1, step=0.1))
    plt.xlabel("False Positive Rate", fontsize=15)
    plt.yticks(np.arange(0.0, 1.1, step=0.1))
    plt.ylabel("True Positive Rate", fontsize=15)
    plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
    plt.legend(prop={'size':13}, loc='lower right')
    plt.show()

#plot_roc_insame(results)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC


# create a set of other models
classifiers = [GaussianNB(), 
               KNeighborsClassifier(n_neighbors=3),
               KNeighborsClassifier(n_neighbors=5), 
               RandomForestClassifier(random_state=2020),
               SVC(kernel="linear", C=0.025, probability=True),
               SVC(kernel="linear", C=0.01, probability=True)
              ]
# perceber as diferenças das abordagens, segundo as mesmas condições..
results = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc','f1', 'mcc', 'confusion_matrix'])
import random
# train !
i = 0
for cls in classifiers:
    results = results.append(model_train_and_evaluate(cls, X_train, y_train, X_test, y_test, str(i)))
    i+=1
# pipeline completo de de fazer lcassificação e avaliar com as métricas, obter X de treino e feature e ir buscar as características (princípio ), camada de classificação estendida e .. métodos mais simples
results.head()
print(results)
plot_roc_insame(results)

# %% [markdown]
# # Neural Network

# %%
dataT = data.iloc[:, 2:]

# %%
dataT

# %%
dataT.shape

# %%
X = dataT

# %%
type(data.iloc[0,0])

# %%
data.iloc[0,:]

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout


#aborgadem mais deep

def Deep_Model(activation = 'linear', neurons = 25, optimizer='Adam', input_size = 145): # a primeira camada o nº = ao número de inputs que estamos a usar (features?), neurónios.. colocar mais?
  model = Sequential() # fazer tuning desta parametrização toda , mais 5 parâmetros de cada lado, e tudo isto tem influência no resultado .. etc Promenores, de que classificadores usar e depende do que queiramos 
  # fully #1       
  model.add(Dense(neurons, input_dim=input_size, activation=activation))
  # fully #2
  model.add(Dense(neurons, activation= activation))
  #droput layer
  model.add(Dropout(0.3)) # filtro para regularizar nossa rede (apagando, parte da informação) treinar todos os seus pesos e não fixa em padrões de pesos. Rede aprende mais nada, dos padrões de peso
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['accuracy'])
  return model

  # ensure the dataset!
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1234)

# create ref to keras model # época é uma passagem pelo dataset completa, viu as 500etal amostras 100 vezes #questão de tunning dos parametros...
clf = KerasClassifier(build_fn=Deep_Model, epochs=100, batch_size=40, verbose=1) # é o que o sklearn usa para ter um modelo igual ao deles ..  etc, para ter um modelo igual aos pesos!

from sklearn.utils import check_X_y
X_train, y_train = check_X_y(X_train, y_train)
X_test, y_test = check_X_y(X_test, y_test)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

yproba = clf.predict_proba(X_test)[::,1]
#yproba = clf.predict.proba(X_test)
ypredicted = clf.predict(X_test)

# extract metrics  tipically   y_true,  y_pred
fpr, tpr, _ = roc_curve(y_test, yproba,  pos_label=2)
auc = roc_auc_score(y_test, yproba)
conf_m = confusion_matrix(y_test, y_pred)
mcc = matthews_corrcoef(y_test, ypredicted)
f1 = f1_score(y_test, ypredicted)

result_table = pd.DataFrame(columns=['classifiers', 'fpr', 'tpr', 'auc', 'f1', 'mcc', 'confusion_matrix'])
result_table = result_table.append({'classifiers':"DNN",
                                    'fpr': fpr,
                                    'tpr': tpr,
                                    'auc': auc,
                                    'confusion_matrix': conf_m,
                                    'mcc': mcc,
                                    'f1': f1}, ignore_index=True)

print('AUC', auc)
print(classification_report(y_test,y_pred))
print(conf_m)

# plot roc curve!
plot_roc_insame(result_table)

result_table.head()

# %% [markdown]
# # 2nd Goal

# %% [markdown]
# **2nd Goal: Reduce time procedures diagnosis: after the first complete goal check, reduce the number of sessions to less than 10**

# %%
sub = '10' #lasts=10
print(data.iloc[0,:].str.find(sub))
#find(data.iloc[0,:].find('10')

# %%
data2g = data.iloc[:,2:]

# %%
# criar função ... para reproduzir
X = data2g # 145 caracteristicas este dataset
y = labels

# uma linha de X bate certo com uma linha de y ... and so on
print(X.iloc[0])
print(y.iloc[0])

lista_vs = [exemplo for exemplo in range(len(y)) if y[exemplo] == 1] # listas por comprensão , filtrar a lista lendo a própria lista (Matrioska effect)
print(lista_vs)
x_vs = X.iloc[lista_vs]
y_vs = y.iloc[lista_vs]
print(len(x_vs))
#
lista_mcs = [exemplo for exemplo in range(len(y)) if y[exemplo] == 0] # operações matriciais, o python poupa muito código ...
print(lista_mcs) 
x_mcs = X.iloc[lista_mcs]
y_mcs = y.iloc[lista_mcs]
print(len(x_mcs)) 
print(len(X))


def model_train_and_evaluate(a_classifier, _x_train, _y_train, _x_test, _y_test, key=""):  # o que acontece com o sklearn, todos os modelos fit e predict tem.. e mudasse o tipo de classificadores aqui

  a_model = a_classifier.fit(_x_train, _y_train) #dá para todos os modelos de classificador que pretenda
# fase de treino e fit -> train , mudou nome das varíaveis para não coincidirem em memória .. é eager precisa dos dados completos para fazer o fit etc
  yproba = a_model.predict_proba(_x_test)[::,1]  # da uma noção e confiança sobre aquela amostra
  ypredicted = a_model.predict(_x_test)
# lista inteira de exemplo, em que depois bate tudo certo...
  # extract metrics  tipically y_true, y_pred # groundtrue  e y que foram previstos.., slides das métricas vai disponibilizar... , matriz de confusão
  fpr, tpr, _ = roc_curve(_y_test, yproba, pos_label=2) #f_measure também!
  auc = roc_auc_score(_y_test, yproba)
  conf_m = confusion_matrix(_y_test, ypredicted) # extraí um conj. de métricas de performance
  mcc = matthews_corrcoef(_y_test, ypredicted)
  f1 = f1_score(_y_test, ypredicted)
  # we can add more..
  result_table = pd.DataFrame(columns=['classifiers', 'fpr', 'tpr', 'auc', 'f1', 'mcc', 'confusion_matrix']) # faz datasets bem construídos e legíveis (dados e visualmente)
  result_table = result_table.append({'classifiers':a_classifier.__class__.__name__+"-"+key,
                                     'fpr':fpr,
                                     'tpr':tpr,
                                     'auc':auc,
                                     'confusion_matrix': conf_m,
                                     'mcc':mcc,
                                     'f1': f1}, ignore_index=True)
  return result_table #fica numa tabela em result





X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1234) # devolve uma lista de variáveis (decomposição) separadas por vírgulas, faz o split do dataset total
print(X_train.shape) # rnadom_state com valor fixo para conseguirmos garantir que conseguimos replicar. 




from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import f1_score

results = model_train_and_evaluate(DecisionTreeClassifier(random_state=2020), X_train, y_train, X_test, y_test) # Aproveitar o classificadores que já existem
results.head()








def plot_roc_insame(result_table):
    result_table.set_index('classifiers', inplace=True)
    
    fig = plt.figure(figsize=(8,6))
    
    for i in result_table.index:
        plt.plot(result_table.loc[i]['fpr'], 
                 result_table.loc[i]['tpr'], 
                 label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
        
    plt.plot([0,1], [0,1], color='black', linestyle='--') # random chance!
    plt.xticks(np.arange(0.0, 1.1, step=0.1))
    plt.xlabel("False Positive Rate", fontsize=15)
    plt.yticks(np.arange(0.0, 1.1, step=0.1))
    plt.ylabel("True Positive Rate", fontsize=15)
    plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
    plt.legend(prop={'size':13}, loc='lower right')
    plt.show()

#plot_roc_insame(results)




from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC


# create a set of other models
classifiers = [GaussianNB(), 
               KNeighborsClassifier(n_neighbors=3),
               KNeighborsClassifier(n_neighbors=5), 
               RandomForestClassifier(random_state=2020),
               SVC(kernel="linear", C=0.025, probability=True),
               SVC(kernel="linear", C=0.01, probability=True)
              ]
# perceber as diferenças das abordagens, segundo as mesmas condições..
results = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc','f1', 'mcc', 'confusion_matrix'])
import random
# train !
i = 0
for cls in classifiers:
    results = results.append(model_train_and_evaluate(cls, X_train, y_train, X_test, y_test, str(i)))
    i+=1
# pipeline completo de de fazer lcassificação e avaliar com as métricas, obter X de treino e feature e ir buscar as características (princípio ), camada de classificação estendida e .. métodos mais simples
results.head()
print(results)
plot_roc_insame(results)

# %%
type(data)

# %%
data2g.iloc[0,:].filter(regex='10$')

# %%
#def droppaColumns:
data2g = data2g.drop(data.filter(regex='10$').columns, axis=1)
#def ciclo interativo e outra de organizar e chama programa

# %%
data2g

# %% [markdown]
# # Random Forest

# %%
# Experimentar Random Forest

from sklearn.ensemble import RandomForestClassifier


X_train, X_test, y_train, y_test = train_test_split(data,df1, stratify=df1)

forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)
y_pred=forest.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
X_train, X_test, y_train, y_test = train_test_split(data,df1, stratify=df1, test_size=0.5)
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)

print("Accuracy on training set {:.2f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set {:.5f}".format(forest.score(X_test, y_test)))

# %%
X_train, X_test, y_train, y_test = train_test_split(data,df1, test_size=0.5) #sem stratify o resultado do test set já desce do 1
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)

print("Accuracy on training set {:.2f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set {:.5f}".format(forest.score(X_test, y_test)))

# %%
"""
Sem efeito
# number of estimators == Number of trees? Sim: /* Não moda lá C */

fig, axes = plt.subplots(2,3,figsize=(20, 10))
for i, (ax, tree) in enumerate(zip(axes.ravel(),forest.estimators_)): # .ravel coloca os arrays num único só (ordena conforme as preferências específicadas)
  ax.set_title("Tree {}".format(i)) #enumera as árvores,  note.nkmk.me/en/python-enumerate-start/
  #mglearn.plots.plot_tree_partition(X_train, y_train, tree, ax=ax)

#mglearn.plots.plot_2d_separator(forest, X_train, fill=True, ax=axes[-1,1], alpha=.4)
axes[-1,1].set_title("Random Forest")
#mglearn.discrete_scatter(X_train[:, 0], X_train[:,1],y_train)

"""

# %%
(pd.Series(forest.feature_importances_, index=data.iloc[0])
  .nlargest(35)
  .plot(kind='barh'))    # some method chaining, because it's sexy!

# %%
# data.iloc[0,2:] tenho de eliminar as ... id e order.

# %% [markdown]
# # SVM
# Suport Vector Machines

# %%
from sklearn.svm import SVC
X_train, X_test, y_train, y_test, train_test_split(
    data,df1,stratify=df1
)
svc = SVC()
svc.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(svc.score(X_train, y_train)))
print("Accuracy on test set: {:.2f}".format(svc.score(X_test, y_test)))

# %% [markdown]
# # Machine Learning para 3 estados

# %%
docDf

# %%
Y3 = docDf.pop('Diagnostic3Levels') # remove column Diag3St and store it in Y3 # Column 7 contains label of Diagnostic3States remove and put it in Y3Df

# %%
Y3

# %%
docDf

# %%
docDf = data.replace(' NA', -1)

# %%
from sklearn.model_selection import train_test_split
X_train3, X_test3, y3_train, y3_test = train_test_split(
    docDf,Y3
)

# %%
print("X_train shape: {}".format(X_train3.shape))
print("y_train shape: {}".format(y3_train.shape))
print("X_test shape: {}".format(X_test3.shape))
print("y_test shape: {}".format(y3_test.shape))

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train3, y3_train)

# %%
y3_pred = knn.predict(X_test3)
print("Test set predictions:\n {}".format(y3_pred))

# %%
print("Test set score: {:.2f}".format(np.mean(y3_pred == y3_test)))

# %%
print("Test set score: {:.2f}".format(knn.score(X_test3,y3_test)))

# %%
type(knn)

# %%
type(docDf)

# %%
docDf.shape[1]

# %%
docDf[:0]#obtain a row with all features of dataframe

# %%
type(docDf[:0])

# %%
'''
def plot_feature_importances_doc(model):
  n_features = docDf.shape[1]
  plt.barh(range(n_features), model.feature_importances_, align='center')
  plt.yticks(np.arange(n_features), docDf.shape[1])
  plt.xlabel("Feature importance")
  plt.ylabel("Feature")
  plt.ylim(-1, n_features)

plot_feature_importances_doc(knn)
'''

# %%
#knn.feature_importances_ doesn't existe for knn, see this: # https://stackoverflow.com/questions/55314345/how-to-find-feature-importance-or-variable-importance-graph-for-knnclassifier
